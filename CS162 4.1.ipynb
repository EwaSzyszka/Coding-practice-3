# %% [markdown]
# # Tkinter

# %% [markdown]
# - Search the internet for images using the search term "Tkinter class diagram".
# - Find a useful diagram which explains the structure of the library.
# - What insights does the diagram provide that you didn't get from reading the documentation?
# - What insights would you have to read the documentation to get?

# %%
from IPython.display import Image
Image("tkinter_UML.png")

# %% [markdown]
# - From the Tkinter class diagram I was able to learn what are the item visibilities, eg. The method cornerA is private and the getRow is public
# - The Objects in the class are CellRef, ASTNode, Number,RangeRef, Function, Visitor and StrReprVisitor
# - The Function object has children within the object ASTNode
# - The mothods in each object are documented in the lower box and the characteristics in the upper box of the object notation

# %% [markdown]
# I would need to read the documentation to learn how exactly to call on each method and how to create an instance of an object

# %% [markdown]
# # Logging

# %% [markdown]
# - Draw a class diagram of the Logging library, including some of the logging handlers, filters, formatters and LogRecord classes.
# - Does this do a better job of describing the library than you were able to last session?

# %%
Image("logging_UML.png")

# %% [markdown]
# I think at this stage this UML diagram does not yet do a better job than the explanation in the previous class, as it has only some basic objects documented and basic interactions. I was also not sure how some of the methods visibility is set, thus at this stage I think the diagram has a lot of room for improvement

# %% [markdown]
# # Class Project

# %% [markdown]
# - Using your new insight, decompose your class project into as many classes as you think you will need.
# - Draw this proposed solution into a UML diagram, bring it to class and be prepared to explain your design decisions to your fellow students.
# - How well does your design separate out different concerns?

# %%
Image("class_UML.png")
